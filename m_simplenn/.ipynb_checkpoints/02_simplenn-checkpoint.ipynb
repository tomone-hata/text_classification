# %%
from simplenn import Simplenn
import pickle
import numpy as np
import pandas as pd
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 学習データ・テストデータの読み込み

# %%
x_train, y_train = None, None
with open('train_data.pickle', 'rb') as rb:
    x_train, y_train = pickle.load(rb)

x_test, y_test = None, None
with open('test_data.pickle', 'rb') as rb:
    x_test, y_test = pickle.load(rb)
    
cost_weight = {}
with open('cost_weight.pickle', 'rb') as rb:
    cost_weight = pickle.load(rb)

# %% [markdown]
# ## 学習モデルの読み込み

# %%
x_dim = 2048
n_classes = 16
snn = Simplenn(x_dim, n_classes, hidden_size=[512,512], batch_size=64, learning_rate=0.001, epochs=10, random_seed=None, dropuout=0.6, class_weight=cost_weight)
# Out:
# Start to building a neural network.
# WARNING:tensorflow:From /Users/tomone_hata/.pyenv/versions/3.6.5/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/tomone_hata/.pyenv/versions/3.6.5/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Scucceeded in building a neural network.

# %% [markdown]
# ## 学習の開始

# %%
train_size = int(len(x_train)  * 0.9)
x_valid, y_valid = x_train[train_size:], y_train[train_size:]
x_train, y_train = x_train[:train_size], y_train[:train_size]
print('Train size        : %i' % len(y_train))
print('Validation size:  %i' % len(y_valid))
snn.train(x_train, y_train, x_valid, y_valid)
# Out:
# Train size        : 6698
# Validation size:  745
# Start to train.
# WARNING:tensorflow:From /Users/tomone_hata/.pyenv/versions/3.6.5/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 6698 samples, validate on 745 samples
# Epoch 1/10
# 6698/6698 [==============================] - 2s 313us/step - loss: 4.9716 - acc: 0.4982 - val_loss: 1.1913 - val_acc: 0.8725
# Epoch 2/10
# 6698/6698 [==============================] - 2s 267us/step - loss: 1.4082 - acc: 0.9088 - val_loss: 0.2715 - val_acc: 0.9638
# Epoch 3/10
# 6698/6698 [==============================] - 2s 315us/step - loss: 0.3473 - acc: 0.9728 - val_loss: 0.1129 - val_acc: 0.9691
# Epoch 4/10
# 6698/6698 [==============================] - 2s 263us/step - loss: 0.1392 - acc: 0.9884 - val_loss: 0.0990 - val_acc: 0.9732
# Epoch 5/10
# 6698/6698 [==============================] - 2s 266us/step - loss: 0.0775 - acc: 0.9927 - val_loss: 0.0977 - val_acc: 0.9745
# Epoch 6/10
# 6698/6698 [==============================] - 2s 273us/step - loss: 0.0495 - acc: 0.9940 - val_loss: 0.0899 - val_acc: 0.9799
# Epoch 7/10
# 6698/6698 [==============================] - 2s 274us/step - loss: 0.0338 - acc: 0.9969 - val_loss: 0.0989 - val_acc: 0.9785
# Epoch 8/10
# 6698/6698 [==============================] - 2s 282us/step - loss: 0.0268 - acc: 0.9981 - val_loss: 0.1062 - val_acc: 0.9758
# Epoch 9/10
# 6698/6698 [==============================] - 2s 267us/step - loss: 0.0227 - acc: 0.9978 - val_loss: 0.1073 - val_acc: 0.9745
# Epoch 10/10
# 6698/6698 [==============================] - 2s 291us/step - loss: 0.0128 - acc: 0.9988 - val_loss: 0.1071 - val_acc: 0.9772
# Scucceeded in training.

# %% [markdown]
# ## 検証

# %%
snn.test( x_test, y_test)
# Out:
# 822/822 [==============================] - 0s 113us/step
# Test loss: 0.2548900760184529
# Test accuracy: 0.9428223839931534

# %%
result = np.zeros((16,16))
y_actually = np.argmax(y_test, axis=1)
y_predict = np.argmax(snn.model.predict(x_test), axis=1)
y_len = y_actually.shape[0]
print(y_len)
for i in range(y_len):
    result[y_actually[i], y_predict[i]] += 1
result = result.astype(int)
# Out:
# 822

# %% [markdown]
# ## 結果の評価

# %%
classify_dict = {'本会議':0, '内閣委員会':1, '総務委員会':2, '法務委員会':3, '外務委員会':4, '財務金融委員会':5, '文部科学委員会':6, '厚生労働委員会':7, '農林水産委員会':8, \
                '経済産業委員会':9, '国土交通委員会':10, '環境委員会':11, '安全保障委員会':12, '予算委員会':13, '決算行政監視委員会':14, '議院運営委員会':15}
classify_dict = {val:key for key, val in classify_dict.items()}
predict_ = ['predict: %s' % classify_dict[i] for i in range(len(classify_dict))]
actually_ = ['actually: %s' % classify_dict[i] for i in range(len(classify_dict))]
pd.DataFrame(result, index=actually_, columns= predict_)
# Out:
#                      predict: 本会議  predict: 内閣委員会  predict: 総務委員会  \
# actually: 本会議                 104               0               0
# actually: 内閣委員会                 1              65               0
# actually: 総務委員会                 0               2              34
# actually: 法務委員会                 0               1               0
# actually: 外務委員会                 0               0               0
# actually: 財務金融委員会               0               0               0
# actually: 文部科学委員会               0               2               0
# actually: 厚生労働委員会               0               3               1
# actually: 農林水産委員会               0               0               0
# actually: 経済産業委員会               0               3               0
# actually: 国土交通委員会               0               3               0
# actually: 環境委員会                 0               1               0
# actually: 安全保障委員会               0               0               0
# actually: 予算委員会                 0               1               0
# actually: 決算行政監視委員会             0               0               0
# actually: 議院運営委員会               0               0               0
#
#                      predict: 法務委員会  predict: 外務委員会  predict: 財務金融委員会  \
# actually: 本会議                     0               0                 0
# actually: 内閣委員会                   0               0                 0
# actually: 総務委員会                   0               0                 0
# actually: 法務委員会                  60               0                 0
# actually: 外務委員会                   0              21                 0
# actually: 財務金融委員会                 0               0                18
# actually: 文部科学委員会                 0               0                 0
# actually: 厚生労働委員会                 0               0                 0
# actually: 農林水産委員会                 0               1                 0
# actually: 経済産業委員会                 0               0                 0
# actually: 国土交通委員会                 0               0                 0
# actually: 環境委員会                   0               0                 0
# actually: 安全保障委員会                 0               0                 0
# actually: 予算委員会                   0               1                 0
# actually: 決算行政監視委員会               0               0                 0
# actually: 議院運営委員会                 0               0                 2
#
#                      predict: 文部科学委員会  predict: 厚生労働委員会  predict: 農林水産委員会  \
